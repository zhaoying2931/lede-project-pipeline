# %%
import pandas as pd
# Out:
# /Users/yingzhao/.pyenv/versions/3.8.10/lib/python3.8/site-packages/pandas/compat/__init__.py:97: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
df = pd.read_csv("data/pipline_serious_incidents.csv")

# %%
df.head()
# Out:
#    Calendar Year Portal Year Incident Cause Type Incident Cause SubType  \
# 0           2001      7/8/21    ALL OTHER CAUSES          MISCELLANEOUS
# 1           2001      7/8/21    ALL OTHER CAUSES          MISCELLANEOUS
# 2           2001      7/8/21    ALL OTHER CAUSES          MISCELLANEOUS
# 3           2001      7/8/21    ALL OTHER CAUSES          MISCELLANEOUS
# 4           2001      7/8/21    ALL OTHER CAUSES          MISCELLANEOUS
#
#   Serious Incident Flag Significant Incident Flag  Unnamed: 6  \
# 0                    No                       Yes           1
# 1                    No                       Yes           1
# 2                    No                       Yes           1
# 3                    No                       Yes           1
# 4                    No                       Yes           1
#
#    # of Fatalities  # of Injuries  Total Property Damage  \
# 0                0              0               750000.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4311 entries, 0 to 4310
# Data columns (total 18 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Calendar Year                         4311 non-null   int64
#  1   Portal Year                           4311 non-null   object
#  2   Incident Cause Type                   4291 non-null   object
#  3   Incident Cause SubType                4291 non-null   object
#  4   Serious Incident Flag                 4311 non-null   object
#  5   Significant Incident Flag             4311 non-null   object
#  6   Unnamed: 6                            4311 non-null   int64
#  7   # of Fatalities                       4311 non-null   int64
#  8   # of Injuries                         4311 non-null   int64
#  9   Total Property Damage                 4310 non-null   float64
#  10  Total Property Damage-Cur Yr Dollars  4311 non-null   float64
# ...

# %%
df['Incident Cause Type'].unique()
# Out:
# array(['ALL OTHER CAUSES', 'CORROSION', 'EXCAVATION DAMAGE',
#        'INCORRECT OPERATION', 'MATERIAL/WELD/EQUIP FAILURE',
#        'NATURAL FORCE DAMAGE', 'OTHER OUTSIDE FORCE DAMAGE', nan],
#       dtype=object)

# %%
df_year_count = df['Calendar Year'].value_counts().to_frame().reset_index()
df_year_count
# Out:
#     index  Calendar Year
# 0    2019            242
# 1    2014            237
# 2    2004            235
# 3    2005            233
# 4    2015            228
# 5    2013            228
# 6    2016            223
# 7    2011            222
# 8    2003            218
# 9    2009            218
# 10   2008            218
# 11   2017            217
# 12   2020            214
# 13   2018            213
# 14   2010            211
# 15   2002            203
# 16   2006            202
# 17   2007            194
# 18   2012            187
# 19   2001            168

# %%
df['Incident Cause Type'].value_counts()
# Out:
# MATERIAL/WELD/EQUIP FAILURE    1320
# EXCAVATION DAMAGE               771
# CORROSION                       583
# OTHER OUTSIDE FORCE DAMAGE      463
# INCORRECT OPERATION             401
# ALL OTHER CAUSES                383
# NATURAL FORCE DAMAGE            370
# Name: Incident Cause Type, dtype: int64

# %%
df['State Name'].value_counts()
# Out:
# TEXAS                   562
# LOUISIANA               332
# CALIFORNIA              276
# OKLAHOMA                217
# KANSAS                  189
# ILLINOIS                187
# PENNSYLVANIA            168
# OCS                     154
# OHIO                    153
# MICHIGAN                136
# NEW YORK                104
# MINNESOTA               102
# NEW MEXICO               97
# MISSOURI                 93
# MISSISSIPPI              86
# INDIANA                  84
# NEW JERSEY               83
# COLORADO                 82
# WYOMING                  79
# GEORGIA                  79
# IOWA                     78
# ALABAMA                  65
# ARKANSAS                 62
# KENTUCKY                 61
# NORTH DAKOTA             58
# NORTH CAROLINA           51
# WISCONSIN                50
# NEBRASKA                 50
# TENNESSEE                49
# VIRGINIA                 49
# FLORIDA                  47
# MARYLAND                 41
# MASSACHUSETTS            39
# ...

# %%
df_gas = pd.read_csv('data/incident_gas_distribution_jan2010_present.csv')

# %%
df_gas.head()
# Out:
#   REPORT_RECEIVED_DATE  IYEAR  REPORT_NUMBER  SUPPLEMENTAL_NUMBER  \
# 0              6/24/21   2021       20210058                35425
# 1              6/24/21   2021       20210059                35433
# 2              6/22/21   2021       20210057                35419
# 3              6/24/21   2021       20210060                35431
# 4              6/21/21   2021       20210056                35415
#
#           REPORT_TYPE  OPERATOR_ID                                NAME  \
# 0            ORIGINAL        15359                  BLACK HILLS ENERGY
# 1  SUPPLEMENTAL FINAL        15359                  BLACK HILLS ENERGY
# 2      ORIGINAL FINAL        15359                  BLACK HILLS ENERGY
# 3      ORIGINAL FINAL        13710            NORTHERN ILLINOIS GAS CO
# 4            ORIGINAL        13730  NORTHERN INDIANA PUBLIC SERVICE CO
#
#          OPERATOR_STREET_ADDRESS OPERATOR_CITY_NAME  \
# 0  2287 COLLEGE ROAD PO BOX 2006     COUNCIL BLUFFS
# ...

# %%
df_gas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Columns: 466 entries, REPORT_RECEIVED_DATE to NARRATIVE
# dtypes: float64(143), int64(10), object(313)
# memory usage: 4.5+ MB

# %%
df_gas.NAME.value_counts().head(20)
# Out:
# PACIFIC GAS & ELECTRIC CO                                                   80
# SOUTHERN CALIFORNIA GAS CO                                                  66
# CONSOLIDATED EDISON CO OF NEW YORK                                          52
# CONSUMERS ENERGY CO                                                         50
# ATMOS ENERGY CORPORATION - MID-TEX                                          45
# ATLANTA GAS LIGHT CO                                                        35
# COLUMBIA GAS OF OHIO INC                                                    30
# SOUTHWEST GAS CORP                                                          30
# WASHINGTON GAS LIGHT CO                                                     24
# KEYSPAN ENERGY DELIVERY - NY CITY                                           22
# NORTHERN ILLINOIS GAS CO                                                    22
# BLACK HILLS ENERGY                                                          21
# ...

# %%
df_liquid = pd.read_csv('data/accident_hazardous_liquid_jan2010_present.csv')

# %%
df_liquid.head()
# Out:
#    IYEAR                                NAME OPERATOR_CITY_NAME  \
# 0   2021       ENTERPRISE CRUDE PIPELINE LLC            HOUSTON
# 1   2021        PERMIAN EXPRESS PARTNERS LLC            HOUSTON
# 2   2021  ROSE ROCK MIDSTREAM OPERATING, LLC            HOUSTON
# 3   2021              EXXONMOBIL PIPELINE CO             SPRING
# 4   2021         DELEK CRUDE LOGISTICS, LLC.             DALLAS
#
#   OPERATOR_STATE_ABBREVIATION  LOCATION_LATITUDE  LOCATION_LONGITUDE  \
# 0                          TX          28.946250          -95.423650
# 1                          TX          29.989279          -94.002547
# 2                          TX          35.927207          -96.760283
# 3                          TX          29.843158          -95.230803
# 4                          TX          32.479730          -94.836680
#
#                              COMMODITY_RELEASED_TYPE  \
# 0                                          CRUDE OIL
# 1                                          CRUDE OIL
# ...

# %%
df_liquid.describe()
# Out:
#              IYEAR  LOCATION_LATITUDE  LOCATION_LONGITUDE  \
# count  4490.000000        4490.000000         4490.000000
# mean   2015.252784          35.317412          -96.317225
# std       3.173111           5.563045           11.262332
# min    2010.000000          18.448010         -158.099930
# 25%    2013.000000          30.444628         -101.366550
# 50%    2015.000000          33.863238          -96.042944
# 75%    2018.000000          39.514508          -92.049095
# max    2021.000000          70.278170          104.263399
#
#        UNINTENTIONAL_RELEASE_BBLS  INTENTIONAL_RELEASE_BBLS  RECOVERED_BBLS  \
# count                 4490.000000               1527.000000     4490.000000
# mean                   222.499862                286.711153       84.710027
# std                   1618.786395               2707.778224      659.602029
# min                      0.000000                  0.000000        0.000000
# ...

# %%
df_liquid.NAME.value_counts().head(20)
# Out:
# ENTERPRISE CRUDE PIPELINE LLC                 319
# ENTERPRISE PRODUCTS OPERATING LLC             254
# SUNOCO PIPELINE L.P.                          239
# PLAINS PIPELINE, L.P.                         234
# MAGELLAN PIPELINE COMPANY, LP                 209
# COLONIAL PIPELINE CO                          198
# BUCKEYE PARTNERS, LP                          167
# KINDER MORGAN LIQUID TERMINALS, LLC           147
# PHILLIPS 66 PIPELINE LLC                      140
# MARATHON PIPE LINE LLC                        120
# ENBRIDGE ENERGY, LIMITED PARTNERSHIP           99
# ONEOK NGL PIPELINE, LLC                        92
# SHELL PIPELINE CO., L.P.                       88
# EXXONMOBIL PIPELINE CO                         77
# EXPLORER PIPELINE CO                           65
# DCP MIDSTREAM                                  55
# MAGELLAN TERMINALS HOLDINGS, LP                49
# SFPP, LP                                       47
# NUSTAR PIPELINE OPERATING PARTNERSHIP L.P.     46
# ...

# %%
df_liquid.COMMODITY_RELEASED_TYPE.value_counts()
# Out:
# CRUDE OIL                                                                             2278
# REFINED AND/OR PETROLEUM PRODUCT (NON-HVL) WHICH IS A LIQUID AT AMBIENT CONDITIONS    1435
# HVL OR OTHER FLAMMABLE OR TOXIC FLUID WHICH IS A GAS AT AMBIENT CONDITIONS             709
# CO2 (CARBON DIOXIDE)                                                                    63
# BIOFUEL / ALTERNATIVE FUEL(INCLUDING ETHANOL BLENDS)                                     5
# Name: COMMODITY_RELEASED_TYPE, dtype: int64

# %%
df_gas = pd.read_csv('data/incident_gas_distribution_jan2010_present.csv')

# %%
df_gas.head()
# Out:
#   REPORT_RECEIVED_DATE  IYEAR  REPORT_NUMBER  SUPPLEMENTAL_NUMBER  \
# 0              6/24/21   2021       20210058                35425
# 1              6/24/21   2021       20210059                35433
# 2              6/22/21   2021       20210057                35419
# 3              6/24/21   2021       20210060                35431
# 4              6/21/21   2021       20210056                35415
#
#           REPORT_TYPE  OPERATOR_ID                                NAME  \
# 0            ORIGINAL        15359                  BLACK HILLS ENERGY
# 1  SUPPLEMENTAL FINAL        15359                  BLACK HILLS ENERGY
# 2      ORIGINAL FINAL        15359                  BLACK HILLS ENERGY
# 3      ORIGINAL FINAL        13710            NORTHERN ILLINOIS GAS CO
# 4            ORIGINAL        13730  NORTHERN INDIANA PUBLIC SERVICE CO
#
#          OPERATOR_STREET_ADDRESS OPERATOR_CITY_NAME  \
# 0  2287 COLLEGE ROAD PO BOX 2006     COUNCIL BLUFFS
# ...

# %%
df_gas_map = df_gas.drop(['REPORT_RECEIVED_DATE','SUPPLEMENTAL_NUMBER','OPERATOR_ID','REPORT_TYPE','OPERATOR_STREET_ADDRESS','OPERATOR_CITY_NAME','PREPARER_TELEPHONE','PREPARER_FAX','LOCAL_CONTACT_NAME','LOCAL_CONTACT_EMAIL','LOCAL_CONTACT_TELEPHONE','AUTHORIZER_NAME','AUTHORIZER_TITLE','AUTHORIZER_TELEPHONE','AUTHORIZER_EMAIL','NARRATIVE'], axis = 1)

# %%
df_gas_map.drop([])
# Out:
#       IYEAR  REPORT_NUMBER                                   NAME  \
# 0      2021       20210058                     BLACK HILLS ENERGY
# 1      2021       20210059                     BLACK HILLS ENERGY
# 2      2021       20210057                     BLACK HILLS ENERGY
# 3      2021       20210060               NORTHERN ILLINOIS GAS CO
# 4      2021       20210056     NORTHERN INDIANA PUBLIC SERVICE CO
# ...     ...            ...                                    ...
# 1248   2010       20110378                          BOSTON GAS CO
# 1249   2010       20100013               NORTHERN ILLINOIS GAS CO
# 1250   2010       20100087                         LACLEDE GAS CO
# 1251   2010       20100022              PACIFIC GAS & ELECTRIC CO
# 1252   2010       20100057  ATMOS ENERGY CORPORATION - WEST TEXAS
#
#      OPERATOR_STATE_ABBREVIATION OPERATOR_POSTAL_CODE LOCAL_DATETIME  \
# 0                             IA                51502  6/19/21 13:16
# ...
